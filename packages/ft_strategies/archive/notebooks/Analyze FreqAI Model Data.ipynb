# %%
import os
from pathlib import Path
os.chdir("/Users/markdregan/Dev/litmus/")
print(Path.cwd())
# Out:
# /Users/markdregan/Dev/litmus

# %%
from joblib import dump, load
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = 'cb_sol_1677788686_trained_df.pkl'
filepath = Path('user_data', 'models', 'LitmusMLDP', 'sub-train-SOL_1677788686', filename)
df = load(open(filepath, 'rb'))

# %%
df
# Out:
#        %-adx_30_SOL/USDTUSDT_3m  %-er_30_SOL/USDTUSDT_3m  \
# 3640                  -0.399139                -0.432218
# 3641                  -0.390056                -0.106209
# 3642                  -0.379461                -0.059105
# 3643                  -0.368661                 0.000253
# 3644                  -0.358220                -0.030537
# ...                         ...                      ...
# 27594                 -0.236531                -0.555535
# 27595                 -0.229780                -0.607715
# 27596                 -0.219627                -0.561744
# 27597                 -0.202447                -0.411572
# 27598                 -0.185840                -0.528073
#
#        %-rocr_30_SOL/USDTUSDT_3m  %-cmf_30_SOL/USDTUSDT_3m  \
# 3640                   -0.227623                 -0.087251
# 3641                   -0.186082                 -0.016856
# 3642                   -0.177280                  0.060777
# ...
